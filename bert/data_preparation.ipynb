# %%
from transformers import BertTokenizer, BertModel
from milvus import default_server, debug_server
from pymilvus import connections, utility, DataType, FieldSchema, CollectionSchema, Collection
import torch
from tqdm import tqdm
import pandas as pd
import numpy as np
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
import re
import ast
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/mirandadrummond/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained('bert-base-uncased')

# %%
def preprocess_text(text):
    # Lowercase
    text = text.lower()
    # Remove punctuation
    text = re.sub(r'[^\w\s]', '', text)
    # Tokenize
    tokens = word_tokenize(text)
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    filtered_tokens = [word for word in tokens if word not in stop_words]
    # Lemmatize
    lemmatizer = WordNetLemmatizer()
    lemmatized_tokens = [lemmatizer.lemmatize(word) for word in filtered_tokens]
    # Join tokens back into string
    preprocessed_text = ' '.join(lemmatized_tokens)
    return preprocessed_text

# %%
def generate_embeddings(text):
    """Generate embeddings for a given piece of text using BERT."""
    preprocessed_text = preprocess_text(text)
    encoded_input = tokenizer(preprocessed_text, return_tensors='pt', truncation=True, max_length=512)
    with torch.no_grad():
        output = model(**encoded_input)
    return output.last_hidden_state[:,0,:].numpy()  # Use the CLS token's embedding

# %%
# Prepare data
arxiv = pd.read_excel('../data/arxiv100.xlsx')
arxiv.head()
# Out:
#                                                title  \
# 0  The Pre-He White Dwarfs in Eclipsing Binaries....
# 1  A Possible Origin of kHZ QPOs in Low-Mass X-ra...
# 2  The effects of driving time scales on heating ...
# 3  A new hard X-ray selected sample of extreme hi...
# 4  The baryon cycle of Seven Dwarfs with superbub...
#
#                                             abstract     label
# 0  We report the first $BV$ light curves and high...  astro-ph
# 1  A possible origin of kHz QPOs in low-mass X-ra...  astro-ph
# 2    Context. The relative importance of AC and D...  astro-ph
# 3  Extreme high-energy peaked BL Lac objects (EHB...  astro-ph
# 4  We present results from a high-resolution, cos...  astro-ph

# %%
tqdm.pandas()
arxiv['embeddings'] = arxiv['abstract'].progress_apply(generate_embeddings)
# Out:
# 100%|██████████| 100000/100000 [1:26:55<00:00, 19.17it/s]

# %%
# convert from shape (1, 768) to  (768,)
arxiv['embeddings'] = arxiv['embeddings'].apply(lambda x: x.flatten())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[129], line 4
#       1 arxiv_e['embeddings'][0].shape
#       3 # convert from shape (1, 768) to  (768,)
# ----> 4 data['embeddings'] = data['embeddings'].apply(lambda x: x.flatten())
#
# TypeError: list indices must be integers or slices, not str
# [2024/04/21 21:41:34.870 +02:00] [INFO] [gc/gc_tuner.go:90] ["GC Tune done"] ["previous GOGC"=200] ["heapuse "=76] ["total memory"=13359] ["next GC"=76] ["new GOGC"=200] [gc-pause=59.416µs] [gc-pause-end=1713728494870447000]
# [2024/04/21 21:41:40.093 +02:00] [INFO] [datacoord/index_service.go:513] ["receive DescribeIndex request"] [traceID=b26107a4bb8019be1fd160939478ad3e] [collectionID=449243396322099465] [indexName=] [timestamp=0]
# [2024/04/21 21:41:40.093 +02:00] [INFO] [datacoord/index_service.go:449] ["completeIndexInfo success"] [collectionID=449243396322099465] [indexID=449243396322099562] [totalRows=12] [indexRows=12] [pendingIndexRows=0] [state=Finished] [failReason=]
# [2024/04/21 21:41:40.093 +02:00] [INFO] [datacoord/index_service.go:560] ["DescribeIndex success"] [traceID=b26107a4bb8019be1fd160939478ad3e] [collectionID=449243396322099465] [indexName=]
# [2024/04/21 21:41:40.093 +02:00] [INFO] [querynodev2/services.go:1370] ["sync action"] [traceID=c7869fa1e45ef160fde0a46b1f2acdf4] [collectionID=449243396322099465] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [currentNodeID=2] [Action=UpdateVersion] [TargetVersion=1713728490096048000]
# [2024/04/21 21:41:40.093 +02:00] [INFO] [delegator/distribution.go:294] ["Update readable segment version"] [oldVersion=1713728480093648000] [newVersion=1713728490096048000] [growingSegmentNum=0] [sealedSegmentNum=1]
# [2024/04/21 21:41:40.093 +02:00] [INFO] [observers/target_observer.go:473] ["observer trigger update current target"] [collectionID=449243396322099465]
# [2024/04/21 21:41:40.093 +02:00] [INFO] [datacoord/services.go:782] ["get recovery info request received"] [traceID=1db3291528b8ffb82bab0d30162f2210] [collectionID=449243396322099465] [partitionIDs="[]"]
# [2024/04/21 21:41:40.093 +02:00] [INFO] [datacoord/handler.go:116] [GetQueryVChanPositions] [collectionID=449243396322099465] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [numOfSegments=1] ["indexed segment"=1]
# [2024/04/21 21:41:40.093 +02:00] [INFO] [datacoord/handler.go:299] ["channel seek position set from channel checkpoint meta"] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [posTs=449243635794837506] [posTime=2024/04/21 21:41:09.066 +02:00]
# [2024/04/21 21:41:40.093 +02:00] [INFO] [datacoord/services.go:797] ["datacoord append channelInfo in GetRecoveryInfo"] [traceID=1db3291528b8ffb82bab0d30162f2210] [collectionID=449243396322099465] [partitionIDs="[]"] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] ["# of unflushed segments"=0] ["# of flushed segments"=1] ["# of dropped segments"=0] ["# of indexed segments"=0]
# [2024/04/21 21:41:40.167 +02:00] [INFO] [runtime/asm_arm64.s:1222] ["expire all shard leader cache"] [database=default] [collections="[arxiv_10000]"]
# [2024/04/21 21:41:50.092 +02:00] [INFO] [datacoord/index_service.go:513] ["receive DescribeIndex request"] [traceID=ea991155e6df27936ac093588dd1112b] [collectionID=449243396322099465] [indexName=] [timestamp=0]
# [2024/04/21 21:41:50.093 +02:00] [INFO] [datacoord/index_service.go:449] ["completeIndexInfo success"] [collectionID=449243396322099465] [indexID=449243396322099562] [totalRows=12] [indexRows=12] [pendingIndexRows=0] [state=Finished] [failReason=]
# [2024/04/21 21:41:50.093 +02:00] [INFO] [datacoord/index_service.go:560] ["DescribeIndex success"] [traceID=ea991155e6df27936ac093588dd1112b] [collectionID=449243396322099465] [indexName=]
# [2024/04/21 21:41:50.094 +02:00] [INFO] [querynodev2/services.go:1370] ["sync action"] [traceID=b0ab31f5b09d1b0a2ca02febf5a7bb4a] [collectionID=449243396322099465] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [currentNodeID=2] [Action=UpdateVersion] [TargetVersion=1713728500093732000]
# [2024/04/21 21:41:50.094 +02:00] [INFO] [delegator/distribution.go:294] ["Update readable segment version"] [oldVersion=1713728490096048000] [newVersion=1713728500093732000] [growingSegmentNum=0] [sealedSegmentNum=1]
# [2024/04/21 21:41:50.094 +02:00] [INFO] [observers/target_observer.go:473] ["observer trigger update current target"] [collectionID=449243396322099465]
# [2024/04/21 21:41:50.094 +02:00] [INFO] [datacoord/services.go:782] ["get recovery info request received"] [traceID=f2f5645ff708114424220797aed08d4f] [collectionID=449243396322099465] [partitionIDs="[]"]
# [2024/04/21 21:41:50.094 +02:00] [INFO] [datacoord/handler.go:116] [GetQueryVChanPositions] [collectionID=449243396322099465] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [numOfSegments=1] ["indexed segment"=1]
# [2024/04/21 21:41:50.094 +02:00] [INFO] [datacoord/handler.go:299] ["channel seek position set from channel checkpoint meta"] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [posTs=449243635794837506] [posTime=2024/04/21 21:41:09.066 +02:00]
# [2024/04/21 21:41:50.094 +02:00] [INFO] [datacoord/services.go:797] ["datacoord append channelInfo in GetRecoveryInfo"] [traceID=f2f5645ff708114424220797aed08d4f] [collectionID=449243396322099465] [partitionIDs="[]"] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] ["# of unflushed segments"=0] ["# of flushed segments"=1] ["# of dropped segments"=0] ["# of indexed segments"=0]
# [2024/04/21 21:41:50.576 +02:00] [INFO] [gc/gc_tuner.go:90] ["GC Tune done"] ["previous GOGC"=200] ["heapuse "=73] ["total memory"=13104] ["next GC"=77] ["new GOGC"=200] [gc-pause=299.834µs] [gc-pause-end=1713728510575832000]
# [2024/04/21 21:41:52.167 +02:00] [INFO] [runtime/asm_arm64.s:1222] ["expire all shard leader cache"] [database=default] [collections="[arxiv_10000]"]
# [2024/04/21 21:42:00.093 +02:00] [INFO] [datacoord/index_service.go:513] ["receive DescribeIndex request"] [traceID=23dcbe7eba0b843f6a8485497dce9ad3] [collectionID=449243396322099465] [indexName=] [timestamp=0]
# [2024/04/21 21:42:00.094 +02:00] [INFO] [datacoord/index_service.go:449] ["completeIndexInfo success"] [collectionID=449243396322099465] [indexID=449243396322099562] [totalRows=12] [indexRows=12] [pendingIndexRows=0] [state=Finished] [failReason=]
# [2024/04/21 21:42:00.094 +02:00] [INFO] [datacoord/index_service.go:560] ["DescribeIndex success"] [traceID=23dcbe7eba0b843f6a8485497dce9ad3] [collectionID=449243396322099465] [indexName=]
# [2024/04/21 21:42:00.094 +02:00] [INFO] [querynodev2/services.go:1370] ["sync action"] [traceID=8b1586f36df2f80922740091d28189a4] [collectionID=449243396322099465] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [currentNodeID=2] [Action=UpdateVersion] [TargetVersion=1713728510094480000]
# [2024/04/21 21:42:00.094 +02:00] [INFO] [delegator/distribution.go:294] ["Update readable segment version"] [oldVersion=1713728500093732000] [newVersion=1713728510094480000] [growingSegmentNum=0] [sealedSegmentNum=1]
# [2024/04/21 21:42:00.094 +02:00] [INFO] [observers/target_observer.go:473] ["observer trigger update current target"] [collectionID=449243396322099465]
# [2024/04/21 21:42:00.095 +02:00] [INFO] [datacoord/services.go:782] ["get recovery info request received"] [traceID=4eeca3fc42c8deefc229511a7ef1f5a8] [collectionID=449243396322099465] [partitionIDs="[]"]
# [2024/04/21 21:42:00.095 +02:00] [INFO] [datacoord/handler.go:116] [GetQueryVChanPositions] [collectionID=449243396322099465] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [numOfSegments=1] ["indexed segment"=1]
# [2024/04/21 21:42:00.095 +02:00] [INFO] [datacoord/handler.go:299] ["channel seek position set from channel checkpoint meta"] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [posTs=449243635794837506] [posTime=2024/04/21 21:41:09.066 +02:00]
# [2024/04/21 21:42:00.095 +02:00] [INFO] [datacoord/services.go:797] ["datacoord append channelInfo in GetRecoveryInfo"] [traceID=4eeca3fc42c8deefc229511a7ef1f5a8] [collectionID=449243396322099465] [partitionIDs="[]"] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] ["# of unflushed segments"=0] ["# of flushed segments"=1] ["# of dropped segments"=0] ["# of indexed segments"=0]
# [2024/04/21 21:42:01.167 +02:00] [INFO] [runtime/asm_arm64.s:1222] ["expire all shard leader cache"] [database=default] [collections="[arxiv_10000]"]
# [2024/04/21 21:42:06.773 +02:00] [INFO] [gc/gc_tuner.go:90] ["GC Tune done"] ["previous GOGC"=200] ["heapuse "=73] ["total memory"=13275] ["next GC"=77] ["new GOGC"=200] [gc-pause=500.542µs] [gc-pause-end=1713728526773571000]
# [2024/04/21 21:42:09.375 +02:00] [INFO] [datacoord/meta.go:1341] ["UpdateChannelCheckpoint done"] [vChannel=by-dev-rootcoord-dml_0_449243396322099465v0] [ts=449243651562799105] [msgID="\ufffd\u0011\ufffd\u0006}\u0008<\u0006"] [time=2024/04/21 21:42:09.216 +02:00]
# [2024/04/21 21:42:10.096 +02:00] [INFO] [datacoord/index_service.go:513] ["receive DescribeIndex request"] [traceID=55a06f36bcd97547e7e0d27f2ff17f0d] [collectionID=449243396322099465] [indexName=] [timestamp=0]
# [2024/04/21 21:42:10.096 +02:00] [INFO] [datacoord/index_service.go:449] ["completeIndexInfo success"] [collectionID=449243396322099465] [indexID=449243396322099562] [totalRows=12] [indexRows=12] [pendingIndexRows=0] [state=Finished] [failReason=]
# [2024/04/21 21:42:10.096 +02:00] [INFO] [datacoord/index_service.go:560] ["DescribeIndex success"] [traceID=55a06f36bcd97547e7e0d27f2ff17f0d] [collectionID=449243396322099465] [indexName=]
# [2024/04/21 21:42:10.096 +02:00] [INFO] [querynodev2/services.go:1370] ["sync action"] [traceID=d8ca5e8119b40cf44b0c4ada52a0790f] [collectionID=449243396322099465] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [currentNodeID=2] [Action=UpdateVersion] [TargetVersion=1713728520094960000]
# [2024/04/21 21:42:10.096 +02:00] [INFO] [delegator/distribution.go:294] ["Update readable segment version"] [oldVersion=1713728510094480000] [newVersion=1713728520094960000] [growingSegmentNum=0] [sealedSegmentNum=1]
# [2024/04/21 21:42:10.096 +02:00] [INFO] [observers/target_observer.go:473] ["observer trigger update current target"] [collectionID=449243396322099465]
# [2024/04/21 21:42:10.097 +02:00] [INFO] [datacoord/services.go:782] ["get recovery info request received"] [traceID=d537c7c35c544fa4fcf4d9efcdff7e74] [collectionID=449243396322099465] [partitionIDs="[]"]
# [2024/04/21 21:42:10.097 +02:00] [INFO] [datacoord/handler.go:116] [GetQueryVChanPositions] [collectionID=449243396322099465] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [numOfSegments=1] ["indexed segment"=1]
# [2024/04/21 21:42:10.097 +02:00] [INFO] [datacoord/handler.go:299] ["channel seek position set from channel checkpoint meta"] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [posTs=449243651562799105] [posTime=2024/04/21 21:42:09.216 +02:00]
# [2024/04/21 21:42:10.097 +02:00] [INFO] [datacoord/services.go:797] ["datacoord append channelInfo in GetRecoveryInfo"] [traceID=d537c7c35c544fa4fcf4d9efcdff7e74] [collectionID=449243396322099465] [partitionIDs="[]"] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] ["# of unflushed segments"=0] ["# of flushed segments"=1] ["# of dropped segments"=0] ["# of indexed segments"=0]
# [2024/04/21 21:42:10.167 +02:00] [INFO] [runtime/asm_arm64.s:1222] ["expire all shard leader cache"] [database=default] [collections="[arxiv_10000]"]
# [2024/04/21 21:42:20.092 +02:00] [INFO] [datacoord/index_service.go:513] ["receive DescribeIndex request"] [traceID=abeb5d7eff04c22a2934bf576097838e] [collectionID=449243396322099465] [indexName=] [timestamp=0]
# [2024/04/21 21:42:20.093 +02:00] [INFO] [datacoord/index_service.go:449] ["completeIndexInfo success"] [collectionID=449243396322099465] [indexID=449243396322099562] [totalRows=12] [indexRows=12] [pendingIndexRows=0] [state=Finished] [failReason=]
# [2024/04/21 21:42:20.093 +02:00] [INFO] [datacoord/index_service.go:560] ["DescribeIndex success"] [traceID=abeb5d7eff04c22a2934bf576097838e] [collectionID=449243396322099465] [indexName=]
# [2024/04/21 21:42:20.093 +02:00] [INFO] [querynodev2/services.go:1370] ["sync action"] [traceID=c36707583bd7eeecfebaa1d64dde4a6c] [collectionID=449243396322099465] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [currentNodeID=2] [Action=UpdateVersion] [TargetVersion=1713728530096894000]
# [2024/04/21 21:42:20.093 +02:00] [INFO] [delegator/distribution.go:294] ["Update readable segment version"] [oldVersion=1713728520094960000] [newVersion=1713728530096894000] [growingSegmentNum=0] [sealedSegmentNum=1]
# [2024/04/21 21:42:20.093 +02:00] [INFO] [observers/target_observer.go:473] ["observer trigger update current target"] [collectionID=449243396322099465]
# [2024/04/21 21:42:20.093 +02:00] [INFO] [datacoord/services.go:782] ["get recovery info request received"] [traceID=e4ff6643215cc225ec910e906d82bcbb] [collectionID=449243396322099465] [partitionIDs="[]"]
# [2024/04/21 21:42:20.093 +02:00] [INFO] [datacoord/handler.go:116] [GetQueryVChanPositions] [collectionID=449243396322099465] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [numOfSegments=1] ["indexed segment"=1]
# [2024/04/21 21:42:20.093 +02:00] [INFO] [datacoord/handler.go:299] ["channel seek position set from channel checkpoint meta"] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [posTs=449243651562799105] [posTime=2024/04/21 21:42:09.216 +02:00]
# [2024/04/21 21:42:20.093 +02:00] [INFO] [datacoord/services.go:797] ["datacoord append channelInfo in GetRecoveryInfo"] [traceID=e4ff6643215cc225ec910e906d82bcbb] [collectionID=449243396322099465] [partitionIDs="[]"] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] ["# of unflushed segments"=0] ["# of flushed segments"=1] ["# of dropped segments"=0] ["# of indexed segments"=0]
# [2024/04/21 21:42:22.170 +02:00] [INFO] [runtime/asm_arm64.s:1222] ["expire all shard leader cache"] [database=default] [collections="[arxiv_10000]"]
# [2024/04/21 21:42:22.390 +02:00] [INFO] [gc/gc_tuner.go:90] ["GC Tune done"] ["previous GOGC"=200] ["heapuse "=73] ["total memory"=13445] ["next GC"=77] ["new GOGC"=200] [gc-pause=578.084µs] [gc-pause-end=1713728542389962000]
# [2024/04/21 21:42:30.093 +02:00] [INFO] [datacoord/index_service.go:513] ["receive DescribeIndex request"] [traceID=d43a5e310230e95eee14113b5f904087] [collectionID=449243396322099465] [indexName=] [timestamp=0]
# [2024/04/21 21:42:30.093 +02:00] [INFO] [datacoord/index_service.go:449] ["completeIndexInfo success"] [collectionID=449243396322099465] [indexID=449243396322099562] [totalRows=12] [indexRows=12] [pendingIndexRows=0] [state=Finished] [failReason=]
# [2024/04/21 21:42:30.093 +02:00] [INFO] [datacoord/index_service.go:560] ["DescribeIndex success"] [traceID=d43a5e310230e95eee14113b5f904087] [collectionID=449243396322099465] [indexName=]
# [2024/04/21 21:42:30.094 +02:00] [INFO] [querynodev2/services.go:1370] ["sync action"] [traceID=d3fadd16f84cfa9b764b7f32aacb5a69] [collectionID=449243396322099465] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [currentNodeID=2] [Action=UpdateVersion] [TargetVersion=1713728540093465000]
# [2024/04/21 21:42:30.095 +02:00] [INFO] [delegator/distribution.go:294] ["Update readable segment version"] [oldVersion=1713728530096894000] [newVersion=1713728540093465000] [growingSegmentNum=0] [sealedSegmentNum=1]
# [2024/04/21 21:42:30.095 +02:00] [INFO] [observers/target_observer.go:473] ["observer trigger update current target"] [collectionID=449243396322099465]
# [2024/04/21 21:42:30.096 +02:00] [INFO] [datacoord/services.go:782] ["get recovery info request received"] [traceID=276271a799ec8c8eb97fe8a92063321a] [collectionID=449243396322099465] [partitionIDs="[]"]
# [2024/04/21 21:42:30.096 +02:00] [INFO] [datacoord/handler.go:116] [GetQueryVChanPositions] [collectionID=449243396322099465] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [numOfSegments=1] ["indexed segment"=1]
# [2024/04/21 21:42:30.096 +02:00] [INFO] [datacoord/handler.go:299] ["channel seek position set from channel checkpoint meta"] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [posTs=449243651562799105] [posTime=2024/04/21 21:42:09.216 +02:00]
# [2024/04/21 21:42:30.096 +02:00] [INFO] [datacoord/services.go:797] ["datacoord append channelInfo in GetRecoveryInfo"] [traceID=276271a799ec8c8eb97fe8a92063321a] [collectionID=449243396322099465] [partitionIDs="[]"] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] ["# of unflushed segments"=0] ["# of flushed segments"=1] ["# of dropped segments"=0] ["# of indexed segments"=0]
# [2024/04/21 21:42:31.166 +02:00] [INFO] [runtime/asm_arm64.s:1222] ["expire all shard leader cache"] [database=default] [collections="[arxiv_10000]"]
# [2024/04/21 21:42:37.970 +02:00] [INFO] [gc/gc_tuner.go:90] ["GC Tune done"] ["previous GOGC"=200] ["heapuse "=73] ["total memory"=13327] ["next GC"=76] ["new GOGC"=200] [gc-pause=178.417µs] [gc-pause-end=1713728557970415000]
# [2024/04/21 21:42:40.092 +02:00] [INFO] [datacoord/index_service.go:513] ["receive DescribeIndex request"] [traceID=73569631e43cd07c7174b25f88289467] [collectionID=449243396322099465] [indexName=] [timestamp=0]
# [2024/04/21 21:42:40.092 +02:00] [INFO] [datacoord/index_service.go:449] ["completeIndexInfo success"] [collectionID=449243396322099465] [indexID=449243396322099562] [totalRows=12] [indexRows=12] [pendingIndexRows=0] [state=Finished] [failReason=]
# [2024/04/21 21:42:40.092 +02:00] [INFO] [datacoord/index_service.go:560] ["DescribeIndex success"] [traceID=73569631e43cd07c7174b25f88289467] [collectionID=449243396322099465] [indexName=]
# [2024/04/21 21:42:40.092 +02:00] [INFO] [querynodev2/services.go:1370] ["sync action"] [traceID=cb902e7e6fe2373405ba4a524bb6b54a] [collectionID=449243396322099465] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [currentNodeID=2] [Action=UpdateVersion] [TargetVersion=1713728550095454000]
# [2024/04/21 21:42:40.092 +02:00] [INFO] [delegator/distribution.go:294] ["Update readable segment version"] [oldVersion=1713728540093465000] [newVersion=1713728550095454000] [growingSegmentNum=0] [sealedSegmentNum=1]
# [2024/04/21 21:42:40.093 +02:00] [INFO] [observers/target_observer.go:473] ["observer trigger update current target"] [collectionID=449243396322099465]
# [2024/04/21 21:42:40.093 +02:00] [INFO] [datacoord/services.go:782] ["get recovery info request received"] [traceID=28f6ad29354a13beac7afc6857ae901a] [collectionID=449243396322099465] [partitionIDs="[]"]
# [2024/04/21 21:42:40.093 +02:00] [INFO] [datacoord/handler.go:116] [GetQueryVChanPositions] [collectionID=449243396322099465] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [numOfSegments=1] ["indexed segment"=1]
# [2024/04/21 21:42:40.093 +02:00] [INFO] [datacoord/handler.go:299] ["channel seek position set from channel checkpoint meta"] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [posTs=449243651562799105] [posTime=2024/04/21 21:42:09.216 +02:00]
# [2024/04/21 21:42:40.093 +02:00] [INFO] [datacoord/services.go:797] ["datacoord append channelInfo in GetRecoveryInfo"] [traceID=28f6ad29354a13beac7afc6857ae901a] [collectionID=449243396322099465] [partitionIDs="[]"] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] ["# of unflushed segments"=0] ["# of flushed segments"=1] ["# of dropped segments"=0] ["# of indexed segments"=0]
# [2024/04/21 21:42:40.166 +02:00] [INFO] [runtime/asm_arm64.s:1222] ["expire all shard leader cache"] [database=default] [collections="[arxiv_10000]"]
# [2024/04/21 21:42:50.092 +02:00] [INFO] [datacoord/index_service.go:513] ["receive DescribeIndex request"] [traceID=8c76d2fa5de28034bd4499b261476344] [collectionID=449243396322099465] [indexName=] [timestamp=0]
# [2024/04/21 21:42:50.092 +02:00] [INFO] [datacoord/index_service.go:449] ["completeIndexInfo success"] [collectionID=449243396322099465] [indexID=449243396322099562] [totalRows=12] [indexRows=12] [pendingIndexRows=0] [state=Finished] [failReason=]
# [2024/04/21 21:42:50.093 +02:00] [INFO] [datacoord/index_service.go:560] ["DescribeIndex success"] [traceID=8c76d2fa5de28034bd4499b261476344] [collectionID=449243396322099465] [indexName=]
# [2024/04/21 21:42:50.093 +02:00] [INFO] [querynodev2/services.go:1370] ["sync action"] [traceID=dcf090a45ab9b2b4d71d3959536b7644] [collectionID=449243396322099465] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [currentNodeID=2] [Action=UpdateVersion] [TargetVersion=1713728560093081000]
# [2024/04/21 21:42:50.093 +02:00] [INFO] [delegator/distribution.go:294] ["Update readable segment version"] [oldVersion=1713728550095454000] [newVersion=1713728560093081000] [growingSegmentNum=0] [sealedSegmentNum=1]
# [2024/04/21 21:42:50.093 +02:00] [INFO] [observers/target_observer.go:473] ["observer trigger update current target"] [collectionID=449243396322099465]
# [2024/04/21 21:42:50.093 +02:00] [INFO] [datacoord/services.go:782] ["get recovery info request received"] [traceID=f7d40dcdfd012116141a2084d7d79408] [collectionID=449243396322099465] [partitionIDs="[]"]
# [2024/04/21 21:42:50.093 +02:00] [INFO] [datacoord/handler.go:116] [GetQueryVChanPositions] [collectionID=449243396322099465] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [numOfSegments=1] ["indexed segment"=1]
# [2024/04/21 21:42:50.093 +02:00] [INFO] [datacoord/handler.go:299] ["channel seek position set from channel checkpoint meta"] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [posTs=449243651562799105] [posTime=2024/04/21 21:42:09.216 +02:00]
# [2024/04/21 21:42:50.093 +02:00] [INFO] [datacoord/services.go:797] ["datacoord append channelInfo in GetRecoveryInfo"] [traceID=f7d40dcdfd012116141a2084d7d79408] [collectionID=449243396322099465] [partitionIDs="[]"] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] ["# of unflushed segments"=0] ["# of flushed segments"=1] ["# of dropped segments"=0] ["# of indexed segments"=0]
# [2024/04/21 21:42:52.166 +02:00] [INFO] [runtime/asm_arm64.s:1222] ["expire all shard leader cache"] [database=default] [collections="[arxiv_10000]"]
# [2024/04/21 21:42:53.729 +02:00] [INFO] [gc/gc_tuner.go:90] ["GC Tune done"] ["previous GOGC"=200] ["heapuse "=76] ["total memory"=13642] ["next GC"=83] ["new GOGC"=200] [gc-pause=287.417µs] [gc-pause-end=1713728573729521000]
# [2024/04/21 21:43:00.092 +02:00] [INFO] [datacoord/index_service.go:513] ["receive DescribeIndex request"] [traceID=c1b72f482e919d633bb82dc742e4d333] [collectionID=449243396322099465] [indexName=] [timestamp=0]
# [2024/04/21 21:43:00.092 +02:00] [INFO] [datacoord/index_service.go:449] ["completeIndexInfo success"] [collectionID=449243396322099465] [indexID=449243396322099562] [totalRows=12] [indexRows=12] [pendingIndexRows=0] [state=Finished] [failReason=]
# [2024/04/21 21:43:00.092 +02:00] [INFO] [datacoord/index_service.go:560] ["DescribeIndex success"] [traceID=c1b72f482e919d633bb82dc742e4d333] [collectionID=449243396322099465] [indexName=]
# [2024/04/21 21:43:00.092 +02:00] [INFO] [querynodev2/services.go:1370] ["sync action"] [traceID=7e2161fcc07e98e238f3e98ff6a9f521] [collectionID=449243396322099465] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [currentNodeID=2] [Action=UpdateVersion] [TargetVersion=1713728570093439000]
# [2024/04/21 21:43:00.092 +02:00] [INFO] [delegator/distribution.go:294] ["Update readable segment version"] [oldVersion=1713728560093081000] [newVersion=1713728570093439000] [growingSegmentNum=0] [sealedSegmentNum=1]
# [2024/04/21 21:43:00.092 +02:00] [INFO] [observers/target_observer.go:473] ["observer trigger update current target"] [collectionID=449243396322099465]
# [2024/04/21 21:43:00.092 +02:00] [INFO] [datacoord/services.go:782] ["get recovery info request received"] [traceID=607581d1121c6429068fdf737a433ba1] [collectionID=449243396322099465] [partitionIDs="[]"]
# [2024/04/21 21:43:00.092 +02:00] [INFO] [datacoord/handler.go:116] [GetQueryVChanPositions] [collectionID=449243396322099465] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [numOfSegments=1] ["indexed segment"=1]
# [2024/04/21 21:43:00.092 +02:00] [INFO] [datacoord/handler.go:299] ["channel seek position set from channel checkpoint meta"] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [posTs=449243651562799105] [posTime=2024/04/21 21:42:09.216 +02:00]
# [2024/04/21 21:43:00.092 +02:00] [INFO] [datacoord/services.go:797] ["datacoord append channelInfo in GetRecoveryInfo"] [traceID=607581d1121c6429068fdf737a433ba1] [collectionID=449243396322099465] [partitionIDs="[]"] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] ["# of unflushed segments"=0] ["# of flushed segments"=1] ["# of dropped segments"=0] ["# of indexed segments"=0]
# [2024/04/21 21:43:01.166 +02:00] [INFO] [runtime/asm_arm64.s:1222] ["expire all shard leader cache"] [database=default] [collections="[arxiv_10000]"]
# [2024/04/21 21:43:09.576 +02:00] [INFO] [datacoord/meta.go:1341] ["UpdateChannelCheckpoint done"] [vChannel=by-dev-rootcoord-dml_0_449243396322099465v0] [ts=449243667343867905] [msgID="'\u0013\ufffd\u0006}\u0008<\u0006"] [time=2024/04/21 21:43:09.416 +02:00]
# [2024/04/21 21:43:10.093 +02:00] [INFO] [datacoord/index_service.go:513] ["receive DescribeIndex request"] [traceID=d19035f0c94be85fb70fb2c7db252de2] [collectionID=449243396322099465] [indexName=] [timestamp=0]
# [2024/04/21 21:43:10.093 +02:00] [INFO] [datacoord/index_service.go:449] ["completeIndexInfo success"] [collectionID=449243396322099465] [indexID=449243396322099562] [totalRows=12] [indexRows=12] [pendingIndexRows=0] [state=Finished] [failReason=]
# [2024/04/21 21:43:10.094 +02:00] [INFO] [datacoord/index_service.go:560] ["DescribeIndex success"] [traceID=d19035f0c94be85fb70fb2c7db252de2] [collectionID=449243396322099465] [indexName=]
# [2024/04/21 21:43:10.095 +02:00] [INFO] [querynodev2/services.go:1370] ["sync action"] [traceID=18bc99a2b012af1c53047c6138cb4ad2] [collectionID=449243396322099465] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [currentNodeID=2] [Action=UpdateVersion] [TargetVersion=1713728580092599000]
# [2024/04/21 21:43:10.095 +02:00] [INFO] [delegator/distribution.go:294] ["Update readable segment version"] [oldVersion=1713728570093439000] [newVersion=1713728580092599000] [growingSegmentNum=0] [sealedSegmentNum=1]
# [2024/04/21 21:43:10.095 +02:00] [INFO] [observers/target_observer.go:473] ["observer trigger update current target"] [collectionID=449243396322099465]
# [2024/04/21 21:43:10.096 +02:00] [INFO] [datacoord/services.go:782] ["get recovery info request received"] [traceID=0029e49abe4fbb9382348cd3834d1125] [collectionID=449243396322099465] [partitionIDs="[]"]
# [2024/04/21 21:43:10.096 +02:00] [INFO] [datacoord/handler.go:116] [GetQueryVChanPositions] [collectionID=449243396322099465] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [numOfSegments=1] ["indexed segment"=1]
# [2024/04/21 21:43:10.096 +02:00] [INFO] [datacoord/handler.go:299] ["channel seek position set from channel checkpoint meta"] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [posTs=449243667343867905] [posTime=2024/04/21 21:43:09.416 +02:00]
# [2024/04/21 21:43:10.096 +02:00] [INFO] [datacoord/services.go:797] ["datacoord append channelInfo in GetRecoveryInfo"] [traceID=0029e49abe4fbb9382348cd3834d1125] [collectionID=449243396322099465] [partitionIDs="[]"] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] ["# of unflushed segments"=0] ["# of flushed segments"=1] ["# of dropped segments"=0] ["# of indexed segments"=0]
# [2024/04/21 21:43:10.166 +02:00] [INFO] [runtime/asm_arm64.s:1222] ["expire all shard leader cache"] [database=default] [collections="[arxiv_10000]"]
# [2024/04/21 21:43:10.170 +02:00] [INFO] [gc/gc_tuner.go:90] ["GC Tune done"] ["previous GOGC"=200] ["heapuse "=77] ["total memory"=13561] ["next GC"=76] ["new GOGC"=200] [gc-pause=113.126µs] [gc-pause-end=1713728590169872000]
# [2024/04/21 21:43:20.093 +02:00] [INFO] [datacoord/index_service.go:513] ["receive DescribeIndex request"] [traceID=ced17a35a3e77f09f0797897f4d28a37] [collectionID=449243396322099465] [indexName=] [timestamp=0]
# [2024/04/21 21:43:20.094 +02:00] [INFO] [datacoord/index_service.go:449] ["completeIndexInfo success"] [collectionID=449243396322099465] [indexID=449243396322099562] [totalRows=12] [indexRows=12] [pendingIndexRows=0] [state=Finished] [failReason=]
# [2024/04/21 21:43:20.094 +02:00] [INFO] [datacoord/index_service.go:560] ["DescribeIndex success"] [traceID=ced17a35a3e77f09f0797897f4d28a37] [collectionID=449243396322099465] [indexName=]
# [2024/04/21 21:43:20.095 +02:00] [INFO] [querynodev2/services.go:1370] ["sync action"] [traceID=d541f4e1a7e179acb0b47adad4d26700] [collectionID=449243396322099465] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [currentNodeID=2] [Action=UpdateVersion] [TargetVersion=1713728590095601000]
# [2024/04/21 21:43:20.095 +02:00] [INFO] [delegator/distribution.go:294] ["Update readable segment version"] [oldVersion=1713728580092599000] [newVersion=1713728590095601000] [growingSegmentNum=0] [sealedSegmentNum=1]
# [2024/04/21 21:43:20.095 +02:00] [INFO] [observers/target_observer.go:473] ["observer trigger update current target"] [collectionID=449243396322099465]
# [2024/04/21 21:43:20.095 +02:00] [INFO] [datacoord/services.go:782] ["get recovery info request received"] [traceID=5c867fa8d1052bfbeb9a9aa5637f1efb] [collectionID=449243396322099465] [partitionIDs="[]"]
# [2024/04/21 21:43:20.095 +02:00] [INFO] [datacoord/handler.go:116] [GetQueryVChanPositions] [collectionID=449243396322099465] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [numOfSegments=1] ["indexed segment"=1]
# [2024/04/21 21:43:20.095 +02:00] [INFO] [datacoord/handler.go:299] ["channel seek position set from channel checkpoint meta"] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [posTs=449243667343867905] [posTime=2024/04/21 21:43:09.416 +02:00]
# [2024/04/21 21:43:20.095 +02:00] [INFO] [datacoord/services.go:797] ["datacoord append channelInfo in GetRecoveryInfo"] [traceID=5c867fa8d1052bfbeb9a9aa5637f1efb] [collectionID=449243396322099465] [partitionIDs="[]"] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] ["# of unflushed segments"=0] ["# of flushed segments"=1] ["# of dropped segments"=0] ["# of indexed segments"=0]
# [2024/04/21 21:43:22.166 +02:00] [INFO] [runtime/asm_arm64.s:1222] ["expire all shard leader cache"] [database=default] [collections="[arxiv_10000]"]
# [2024/04/21 21:43:24.575 +02:00] [INFO] [gc/gc_tuner.go:90] ["GC Tune done"] ["previous GOGC"=200] ["heapuse "=69] ["total memory"=13582] ["next GC"=76] ["new GOGC"=200] [gc-pause=228.666µs] [gc-pause-end=1713728604575261000]
# [2024/04/21 21:43:30.092 +02:00] [INFO] [datacoord/index_service.go:513] ["receive DescribeIndex request"] [traceID=4a2564b23771a0a4ec51fda3bd4da42b] [collectionID=449243396322099465] [indexName=] [timestamp=0]
# [2024/04/21 21:43:30.092 +02:00] [INFO] [datacoord/index_service.go:449] ["completeIndexInfo success"] [collectionID=449243396322099465] [indexID=449243396322099562] [totalRows=12] [indexRows=12] [pendingIndexRows=0] [state=Finished] [failReason=]
# [2024/04/21 21:43:30.092 +02:00] [INFO] [datacoord/index_service.go:560] ["DescribeIndex success"] [traceID=4a2564b23771a0a4ec51fda3bd4da42b] [collectionID=449243396322099465] [indexName=]
# [2024/04/21 21:43:30.092 +02:00] [INFO] [querynodev2/services.go:1370] ["sync action"] [traceID=1e4ded6e1d1db748cc904e508034c19d] [collectionID=449243396322099465] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [currentNodeID=2] [Action=UpdateVersion] [TargetVersion=1713728600095404000]
# [2024/04/21 21:43:30.092 +02:00] [INFO] [delegator/distribution.go:294] ["Update readable segment version"] [oldVersion=1713728590095601000] [newVersion=1713728600095404000] [growingSegmentNum=0] [sealedSegmentNum=1]
# [2024/04/21 21:43:30.092 +02:00] [INFO] [observers/target_observer.go:473] ["observer trigger update current target"] [collectionID=449243396322099465]
# [2024/04/21 21:43:30.092 +02:00] [INFO] [datacoord/services.go:782] ["get recovery info request received"] [traceID=3cc00a3c94d01fbf0f70bf7d3ff97e88] [collectionID=449243396322099465] [partitionIDs="[]"]
# [2024/04/21 21:43:30.093 +02:00] [INFO] [datacoord/handler.go:116] [GetQueryVChanPositions] [collectionID=449243396322099465] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [numOfSegments=1] ["indexed segment"=1]
# [2024/04/21 21:43:30.093 +02:00] [INFO] [datacoord/handler.go:299] ["channel seek position set from channel checkpoint meta"] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [posTs=449243667343867905] [posTime=2024/04/21 21:43:09.416 +02:00]
# [2024/04/21 21:43:30.093 +02:00] [INFO] [datacoord/services.go:797] ["datacoord append channelInfo in GetRecoveryInfo"] [traceID=3cc00a3c94d01fbf0f70bf7d3ff97e88] [collectionID=449243396322099465] [partitionIDs="[]"] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] ["# of unflushed segments"=0] ["# of flushed segments"=1] ["# of dropped segments"=0] ["# of indexed segments"=0]
# [2024/04/21 21:43:31.166 +02:00] [INFO] [runtime/asm_arm64.s:1222] ["expire all shard leader cache"] [database=default] [collections="[arxiv_10000]"]
# [2024/04/21 21:43:39.472 +02:00] [INFO] [gc/gc_tuner.go:90] ["GC Tune done"] ["previous GOGC"=200] ["heapuse "=70] ["total memory"=13414] ["next GC"=76] ["new GOGC"=200] [gc-pause=103.875µs] [gc-pause-end=1713728619472463000]
# [2024/04/21 21:43:40.091 +02:00] [INFO] [datacoord/index_service.go:513] ["receive DescribeIndex request"] [traceID=ca7127f3187c4f99f13e9fb6db2767fd] [collectionID=449243396322099465] [indexName=] [timestamp=0]
# [2024/04/21 21:43:40.091 +02:00] [INFO] [datacoord/index_service.go:449] ["completeIndexInfo success"] [collectionID=449243396322099465] [indexID=449243396322099562] [totalRows=12] [indexRows=12] [pendingIndexRows=0] [state=Finished] [failReason=]
# [2024/04/21 21:43:40.091 +02:00] [INFO] [datacoord/index_service.go:560] ["DescribeIndex success"] [traceID=ca7127f3187c4f99f13e9fb6db2767fd] [collectionID=449243396322099465] [indexName=]
# [2024/04/21 21:43:40.092 +02:00] [INFO] [querynodev2/services.go:1370] ["sync action"] [traceID=0405d009d2c185f2c79d778bb90a0f4b] [collectionID=449243396322099465] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [currentNodeID=2] [Action=UpdateVersion] [TargetVersion=1713728610092787000]
# [2024/04/21 21:43:40.092 +02:00] [INFO] [delegator/distribution.go:294] ["Update readable segment version"] [oldVersion=1713728600095404000] [newVersion=1713728610092787000] [growingSegmentNum=0] [sealedSegmentNum=1]
# [2024/04/21 21:43:40.092 +02:00] [INFO] [observers/target_observer.go:473] ["observer trigger update current target"] [collectionID=449243396322099465]
# [2024/04/21 21:43:40.093 +02:00] [INFO] [datacoord/services.go:782] ["get recovery info request received"] [traceID=f79e83797dbec298a95507242e9eea49] [collectionID=449243396322099465] [partitionIDs="[]"]
# [2024/04/21 21:43:40.093 +02:00] [INFO] [datacoord/handler.go:116] [GetQueryVChanPositions] [collectionID=449243396322099465] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [numOfSegments=1] ["indexed segment"=1]
# [2024/04/21 21:43:40.093 +02:00] [INFO] [datacoord/handler.go:299] ["channel seek position set from channel checkpoint meta"] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [posTs=449243667343867905] [posTime=2024/04/21 21:43:09.416 +02:00]
# [2024/04/21 21:43:40.093 +02:00] [INFO] [datacoord/services.go:797] ["datacoord append channelInfo in GetRecoveryInfo"] [traceID=f79e83797dbec298a95507242e9eea49] [collectionID=449243396322099465] [partitionIDs="[]"] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] ["# of unflushed segments"=0] ["# of flushed segments"=1] ["# of dropped segments"=0] ["# of indexed segments"=0]
# [2024/04/21 21:43:40.166 +02:00] [INFO] [runtime/asm_arm64.s:1222] ["expire all shard leader cache"] [database=default] [collections="[arxiv_10000]"]
# [2024/04/21 21:43:50.095 +02:00] [INFO] [datacoord/index_service.go:513] ["receive DescribeIndex request"] [traceID=54716577648a8115e886c761deb39307] [collectionID=449243396322099465] [indexName=] [timestamp=0]
# [2024/04/21 21:43:50.095 +02:00] [INFO] [datacoord/index_service.go:449] ["completeIndexInfo success"] [collectionID=449243396322099465] [indexID=449243396322099562] [totalRows=12] [indexRows=12] [pendingIndexRows=0] [state=Finished] [failReason=]
# [2024/04/21 21:43:50.095 +02:00] [INFO] [datacoord/index_service.go:560] ["DescribeIndex success"] [traceID=54716577648a8115e886c761deb39307] [collectionID=449243396322099465] [indexName=]
# [2024/04/21 21:43:50.097 +02:00] [INFO] [querynodev2/services.go:1370] ["sync action"] [traceID=61c19fafd8e4a2a16119268398a4fb5a] [collectionID=449243396322099465] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [currentNodeID=2] [Action=UpdateVersion] [TargetVersion=1713728620092515000]
# [2024/04/21 21:43:50.097 +02:00] [INFO] [delegator/distribution.go:294] ["Update readable segment version"] [oldVersion=1713728610092787000] [newVersion=1713728620092515000] [growingSegmentNum=0] [sealedSegmentNum=1]
# [2024/04/21 21:43:50.097 +02:00] [INFO] [observers/target_observer.go:473] ["observer trigger update current target"] [collectionID=449243396322099465]
# [2024/04/21 21:43:50.097 +02:00] [INFO] [datacoord/services.go:782] ["get recovery info request received"] [traceID=6fc72178becee5b99e90de019fd291bb] [collectionID=449243396322099465] [partitionIDs="[]"]
# [2024/04/21 21:43:50.097 +02:00] [INFO] [datacoord/handler.go:116] [GetQueryVChanPositions] [collectionID=449243396322099465] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [numOfSegments=1] ["indexed segment"=1]
# [2024/04/21 21:43:50.098 +02:00] [INFO] [datacoord/handler.go:299] ["channel seek position set from channel checkpoint meta"] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [posTs=449243667343867905] [posTime=2024/04/21 21:43:09.416 +02:00]
# [2024/04/21 21:43:50.098 +02:00] [INFO] [datacoord/services.go:797] ["datacoord append channelInfo in GetRecoveryInfo"] [traceID=6fc72178becee5b99e90de019fd291bb] [collectionID=449243396322099465] [partitionIDs="[]"] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] ["# of unflushed segments"=0] ["# of flushed segments"=1] ["# of dropped segments"=0] ["# of indexed segments"=0]
# [2024/04/21 21:43:52.166 +02:00] [INFO] [runtime/asm_arm64.s:1222] ["expire all shard leader cache"] [database=default] [collections="[arxiv_10000]"]
# [2024/04/21 21:43:53.973 +02:00] [INFO] [gc/gc_tuner.go:90] ["GC Tune done"] ["previous GOGC"=200] ["heapuse "=70] ["total memory"=13604] ["next GC"=77] ["new GOGC"=200] [gc-pause=377.708µs] [gc-pause-end=1713728633972784000]
# [2024/04/21 21:43:55.625 +02:00] [INFO] [datacoord/policy.go:561] ["node channel count is not much larger than average, skip reallocate"] [nodeID=2] [channelCount=1] [channelCountPerNode=1]
# [2024/04/21 21:43:55.625 +02:00] [INFO] [datacoord/policy.go:580] ["Channel Balancer got new reAllocations:"] [reAllocations="[]"]
# [2024/04/21 21:43:55.625 +02:00] [INFO] [datacoord/channel_manager.go:274] ["channel manager bg check balance"] [toReleases="[]"]
# [2024/04/21 21:44:00.092 +02:00] [INFO] [datacoord/index_service.go:513] ["receive DescribeIndex request"] [traceID=54bbd43bba4f4a6d8bedbfefdd2b45b0] [collectionID=449243396322099465] [indexName=] [timestamp=0]
# [2024/04/21 21:44:00.092 +02:00] [INFO] [datacoord/index_service.go:449] ["completeIndexInfo success"] [collectionID=449243396322099465] [indexID=449243396322099562] [totalRows=12] [indexRows=12] [pendingIndexRows=0] [state=Finished] [failReason=]
# [2024/04/21 21:44:00.092 +02:00] [INFO] [datacoord/index_service.go:560] ["DescribeIndex success"] [traceID=54bbd43bba4f4a6d8bedbfefdd2b45b0] [collectionID=449243396322099465] [indexName=]
# [2024/04/21 21:44:00.093 +02:00] [INFO] [querynodev2/services.go:1370] ["sync action"] [traceID=772930c70b0b1cf5f5bbc9e8e536d992] [collectionID=449243396322099465] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [currentNodeID=2] [Action=UpdateVersion] [TargetVersion=1713728630097470000]
# [2024/04/21 21:44:00.093 +02:00] [INFO] [delegator/distribution.go:294] ["Update readable segment version"] [oldVersion=1713728620092515000] [newVersion=1713728630097470000] [growingSegmentNum=0] [sealedSegmentNum=1]
# [2024/04/21 21:44:00.093 +02:00] [INFO] [observers/target_observer.go:473] ["observer trigger update current target"] [collectionID=449243396322099465]
# [2024/04/21 21:44:00.093 +02:00] [INFO] [datacoord/services.go:782] ["get recovery info request received"] [traceID=a06695ddb0cdac92f33a01698bbbca46] [collectionID=449243396322099465] [partitionIDs="[]"]
# [2024/04/21 21:44:00.093 +02:00] [INFO] [datacoord/handler.go:116] [GetQueryVChanPositions] [collectionID=449243396322099465] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [numOfSegments=1] ["indexed segment"=1]
# [2024/04/21 21:44:00.093 +02:00] [INFO] [datacoord/handler.go:299] ["channel seek position set from channel checkpoint meta"] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [posTs=449243667343867905] [posTime=2024/04/21 21:43:09.416 +02:00]
# [2024/04/21 21:44:00.093 +02:00] [INFO] [datacoord/services.go:797] ["datacoord append channelInfo in GetRecoveryInfo"] [traceID=a06695ddb0cdac92f33a01698bbbca46] [collectionID=449243396322099465] [partitionIDs="[]"] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] ["# of unflushed segments"=0] ["# of flushed segments"=1] ["# of dropped segments"=0] ["# of indexed segments"=0]
# [2024/04/21 21:44:01.166 +02:00] [INFO] [runtime/asm_arm64.s:1222] ["expire all shard leader cache"] [database=default] [collections="[arxiv_10000]"]
# [2024/04/21 21:44:08.770 +02:00] [INFO] [gc/gc_tuner.go:90] ["GC Tune done"] ["previous GOGC"=200] ["heapuse "=71] ["total memory"=13029] ["next GC"=76] ["new GOGC"=200] [gc-pause=135.834µs] [gc-pause-end=1713728648769821000]
# [2024/04/21 21:44:09.774 +02:00] [INFO] [datacoord/meta.go:1341] ["UpdateChannelCheckpoint done"] [vChannel=by-dev-rootcoord-dml_0_449243396322099465v0] [ts=449243683124674561] [msgID="T\u0014\ufffd\u0006}\u0008<\u0006"] [time=2024/04/21 21:44:09.615 +02:00]
# [2024/04/21 21:44:10.092 +02:00] [INFO] [datacoord/index_service.go:513] ["receive DescribeIndex request"] [traceID=c998e4d88a73ae8013d8983de21bd5dd] [collectionID=449243396322099465] [indexName=] [timestamp=0]
# [2024/04/21 21:44:10.092 +02:00] [INFO] [datacoord/index_service.go:449] ["completeIndexInfo success"] [collectionID=449243396322099465] [indexID=449243396322099562] [totalRows=12] [indexRows=12] [pendingIndexRows=0] [state=Finished] [failReason=]
# [2024/04/21 21:44:10.092 +02:00] [INFO] [datacoord/index_service.go:560] ["DescribeIndex success"] [traceID=c998e4d88a73ae8013d8983de21bd5dd] [collectionID=449243396322099465] [indexName=]
# [2024/04/21 21:44:10.092 +02:00] [INFO] [querynodev2/services.go:1370] ["sync action"] [traceID=618c668010fad9b90ba9fb7c29f9cb8b] [collectionID=449243396322099465] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [currentNodeID=2] [Action=UpdateVersion] [TargetVersion=1713728640093385000]
# [2024/04/21 21:44:10.092 +02:00] [INFO] [delegator/distribution.go:294] ["Update readable segment version"] [oldVersion=1713728630097470000] [newVersion=1713728640093385000] [growingSegmentNum=0] [sealedSegmentNum=1]
# [2024/04/21 21:44:10.092 +02:00] [INFO] [observers/target_observer.go:473] ["observer trigger update current target"] [collectionID=449243396322099465]
# [2024/04/21 21:44:10.092 +02:00] [INFO] [datacoord/services.go:782] ["get recovery info request received"] [traceID=65a0ca49cc967e45af3bbabb647a4d34] [collectionID=449243396322099465] [partitionIDs="[]"]
# [2024/04/21 21:44:10.092 +02:00] [INFO] [datacoord/handler.go:116] [GetQueryVChanPositions] [collectionID=449243396322099465] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [numOfSegments=1] ["indexed segment"=1]
# [2024/04/21 21:44:10.092 +02:00] [INFO] [datacoord/handler.go:299] ["channel seek position set from channel checkpoint meta"] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [posTs=449243683124674561] [posTime=2024/04/21 21:44:09.615 +02:00]
# [2024/04/21 21:44:10.092 +02:00] [INFO] [datacoord/services.go:797] ["datacoord append channelInfo in GetRecoveryInfo"] [traceID=65a0ca49cc967e45af3bbabb647a4d34] [collectionID=449243396322099465] [partitionIDs="[]"] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] ["# of unflushed segments"=0] ["# of flushed segments"=1] ["# of dropped segments"=0] ["# of indexed segments"=0]
# [2024/04/21 21:44:10.166 +02:00] [INFO] [runtime/asm_arm64.s:1222] ["expire all shard leader cache"] [database=default] [collections="[arxiv_10000]"]
# [2024/04/21 21:44:20.092 +02:00] [INFO] [datacoord/index_service.go:513] ["receive DescribeIndex request"] [traceID=fed628c45c37357b7e7d2fe6abef2a81] [collectionID=449243396322099465] [indexName=] [timestamp=0]
# [2024/04/21 21:44:20.094 +02:00] [INFO] [datacoord/index_service.go:449] ["completeIndexInfo success"] [collectionID=449243396322099465] [indexID=449243396322099562] [totalRows=12] [indexRows=12] [pendingIndexRows=0] [state=Finished] [failReason=]
# [2024/04/21 21:44:20.094 +02:00] [INFO] [datacoord/index_service.go:560] ["DescribeIndex success"] [traceID=fed628c45c37357b7e7d2fe6abef2a81] [collectionID=449243396322099465] [indexName=]
# [2024/04/21 21:44:20.094 +02:00] [INFO] [querynodev2/services.go:1370] ["sync action"] [traceID=245c63424d022f34b59c6f2fac8cfa35] [collectionID=449243396322099465] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [currentNodeID=2] [Action=UpdateVersion] [TargetVersion=1713728650092509000]
# [2024/04/21 21:44:20.094 +02:00] [INFO] [delegator/distribution.go:294] ["Update readable segment version"] [oldVersion=1713728640093385000] [newVersion=1713728650092509000] [growingSegmentNum=0] [sealedSegmentNum=1]
# [2024/04/21 21:44:20.095 +02:00] [INFO] [observers/target_observer.go:473] ["observer trigger update current target"] [collectionID=449243396322099465]
# [2024/04/21 21:44:20.095 +02:00] [INFO] [datacoord/services.go:782] ["get recovery info request received"] [traceID=30b075e45fc7b6b4cc90a536c6088c79] [collectionID=449243396322099465] [partitionIDs="[]"]
# [2024/04/21 21:44:20.095 +02:00] [INFO] [datacoord/handler.go:116] [GetQueryVChanPositions] [collectionID=449243396322099465] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [numOfSegments=1] ["indexed segment"=1]
# [2024/04/21 21:44:20.095 +02:00] [INFO] [datacoord/handler.go:299] ["channel seek position set from channel checkpoint meta"] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [posTs=449243683124674561] [posTime=2024/04/21 21:44:09.615 +02:00]
# [2024/04/21 21:44:20.095 +02:00] [INFO] [datacoord/services.go:797] ["datacoord append channelInfo in GetRecoveryInfo"] [traceID=30b075e45fc7b6b4cc90a536c6088c79] [collectionID=449243396322099465] [partitionIDs="[]"] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] ["# of unflushed segments"=0] ["# of flushed segments"=1] ["# of dropped segments"=0] ["# of indexed segments"=0]
# [2024/04/21 21:44:22.166 +02:00] [INFO] [runtime/asm_arm64.s:1222] ["expire all shard leader cache"] [database=default] [collections="[arxiv_10000]"]
# [2024/04/21 21:44:23.732 +02:00] [INFO] [gc/gc_tuner.go:90] ["GC Tune done"] ["previous GOGC"=200] ["heapuse "=71] ["total memory"=12973] ["next GC"=79] ["new GOGC"=200] [gc-pause=223.292µs] [gc-pause-end=1713728663731964000]
# [2024/04/21 21:44:30.094 +02:00] [INFO] [datacoord/index_service.go:513] ["receive DescribeIndex request"] [traceID=368f08e1347fece2862b5b75a03a9591] [collectionID=449243396322099465] [indexName=] [timestamp=0]
# [2024/04/21 21:44:30.094 +02:00] [INFO] [datacoord/index_service.go:449] ["completeIndexInfo success"] [collectionID=449243396322099465] [indexID=449243396322099562] [totalRows=12] [indexRows=12] [pendingIndexRows=0] [state=Finished] [failReason=]
# [2024/04/21 21:44:30.094 +02:00] [INFO] [datacoord/index_service.go:560] ["DescribeIndex success"] [traceID=368f08e1347fece2862b5b75a03a9591] [collectionID=449243396322099465] [indexName=]
# ...
# [2024/04/21 22:02:40.123 +02:00] [INFO] [datacoord/index_service.go:449] ["completeIndexInfo success"] [collectionID=449243396322099465] [indexID=449243396322099562] [totalRows=12] [indexRows=12] [pendingIndexRows=0] [state=Finished] [failReason=]
# [2024/04/21 22:02:40.123 +02:00] [INFO] [datacoord/index_service.go:560] ["DescribeIndex success"] [traceID=9542946c261adc51331c4d665cbab504] [collectionID=449243396322099465] [indexName=]
# [2024/04/21 22:02:40.123 +02:00] [INFO] [querynodev2/services.go:1370] ["sync action"] [traceID=55817d61e6d37b658f21a2833e0cfe58] [collectionID=449243396322099465] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [currentNodeID=2] [Action=UpdateVersion] [TargetVersion=1713729750123816000]
# [2024/04/21 22:02:40.123 +02:00] [INFO] [delegator/distribution.go:294] ["Update readable segment version"] [oldVersion=1713729740123306000] [newVersion=1713729750123816000] [growingSegmentNum=0] [sealedSegmentNum=1]
# [2024/04/21 22:02:40.123 +02:00] [INFO] [observers/target_observer.go:473] ["observer trigger update current target"] [collectionID=449243396322099465]
# [2024/04/21 22:02:40.123 +02:00] [INFO] [datacoord/services.go:782] ["get recovery info request received"] [traceID=8751c9f27ed38774d07eacd8cdae2b68] [collectionID=449243396322099465] [partitionIDs="[]"]
# [2024/04/21 22:02:40.123 +02:00] [INFO] [datacoord/handler.go:116] [GetQueryVChanPositions] [collectionID=449243396322099465] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [numOfSegments=1] ["indexed segment"=1]
# [2024/04/21 22:02:40.123 +02:00] [INFO] [datacoord/handler.go:299] ["channel seek position set from channel checkpoint meta"] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [posTs=449243966733287426] [posTime=2024/04/21 22:02:11.496 +02:00]
# [2024/04/21 22:02:40.123 +02:00] [INFO] [datacoord/services.go:797] ["datacoord append channelInfo in GetRecoveryInfo"] [traceID=8751c9f27ed38774d07eacd8cdae2b68] [collectionID=449243396322099465] [partitionIDs="[]"] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] ["# of unflushed segments"=0] ["# of flushed segments"=1] ["# of dropped segments"=0] ["# of indexed segments"=0]
# [2024/04/21 22:02:40.196 +02:00] [INFO] [runtime/asm_arm64.s:1222] ["expire all shard leader cache"] [database=default] [collections="[arxiv_10000]"]
# [2024/04/21 22:02:50.122 +02:00] [INFO] [datacoord/index_service.go:513] ["receive DescribeIndex request"] [traceID=db438d753c07c1611e7452e0ec205e11] [collectionID=449243396322099465] [indexName=] [timestamp=0]
# [2024/04/21 22:02:50.123 +02:00] [INFO] [datacoord/index_service.go:449] ["completeIndexInfo success"] [collectionID=449243396322099465] [indexID=449243396322099562] [totalRows=12] [indexRows=12] [pendingIndexRows=0] [state=Finished] [failReason=]
# [2024/04/21 22:02:50.123 +02:00] [INFO] [datacoord/index_service.go:560] ["DescribeIndex success"] [traceID=db438d753c07c1611e7452e0ec205e11] [collectionID=449243396322099465] [indexName=]
# [2024/04/21 22:02:50.123 +02:00] [INFO] [querynodev2/services.go:1370] ["sync action"] [traceID=d67946b08018c512620598cb76e94d9c] [collectionID=449243396322099465] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [currentNodeID=2] [Action=UpdateVersion] [TargetVersion=1713729760123678000]
# [2024/04/21 22:02:50.124 +02:00] [INFO] [delegator/distribution.go:294] ["Update readable segment version"] [oldVersion=1713729750123816000] [newVersion=1713729760123678000] [growingSegmentNum=0] [sealedSegmentNum=1]
# [2024/04/21 22:02:50.124 +02:00] [INFO] [observers/target_observer.go:473] ["observer trigger update current target"] [collectionID=449243396322099465]
# [2024/04/21 22:02:50.124 +02:00] [INFO] [datacoord/services.go:782] ["get recovery info request received"] [traceID=4d6dea03eb1b666c5ba6802d7222b493] [collectionID=449243396322099465] [partitionIDs="[]"]
# [2024/04/21 22:02:50.124 +02:00] [INFO] [datacoord/handler.go:116] [GetQueryVChanPositions] [collectionID=449243396322099465] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [numOfSegments=1] ["indexed segment"=1]
# [2024/04/21 22:02:50.124 +02:00] [INFO] [datacoord/handler.go:299] ["channel seek position set from channel checkpoint meta"] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [posTs=449243966733287426] [posTime=2024/04/21 22:02:11.496 +02:00]
# [2024/04/21 22:02:50.124 +02:00] [INFO] [datacoord/services.go:797] ["datacoord append channelInfo in GetRecoveryInfo"] [traceID=4d6dea03eb1b666c5ba6802d7222b493] [collectionID=449243396322099465] [partitionIDs="[]"] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] ["# of unflushed segments"=0] ["# of flushed segments"=1] ["# of dropped segments"=0] ["# of indexed segments"=0]
# [2024/04/21 22:02:51.900 +02:00] [INFO] [gc/gc_tuner.go:90] ["GC Tune done"] ["previous GOGC"=200] ["heapuse "=76] ["total memory"=13489] ["next GC"=76] ["new GOGC"=200] [gc-pause=131.25µs] [gc-pause-end=1713729771899760000]
# [2024/04/21 22:02:52.196 +02:00] [INFO] [runtime/asm_arm64.s:1222] ["expire all shard leader cache"] [database=default] [collections="[arxiv_10000]"]
# [2024/04/21 22:03:00.122 +02:00] [INFO] [datacoord/index_service.go:513] ["receive DescribeIndex request"] [traceID=703e942d04e27b5df8450a0ce4489bf8] [collectionID=449243396322099465] [indexName=] [timestamp=0]
# [2024/04/21 22:03:00.123 +02:00] [INFO] [datacoord/index_service.go:449] ["completeIndexInfo success"] [collectionID=449243396322099465] [indexID=449243396322099562] [totalRows=12] [indexRows=12] [pendingIndexRows=0] [state=Finished] [failReason=]
# [2024/04/21 22:03:00.123 +02:00] [INFO] [datacoord/index_service.go:560] ["DescribeIndex success"] [traceID=703e942d04e27b5df8450a0ce4489bf8] [collectionID=449243396322099465] [indexName=]
# [2024/04/21 22:03:00.123 +02:00] [INFO] [querynodev2/services.go:1370] ["sync action"] [traceID=a57f2f6d81e4b82ea1b2c2b35e9939f3] [collectionID=449243396322099465] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [currentNodeID=2] [Action=UpdateVersion] [TargetVersion=1713729770124152000]
# [2024/04/21 22:03:00.123 +02:00] [INFO] [delegator/distribution.go:294] ["Update readable segment version"] [oldVersion=1713729760123678000] [newVersion=1713729770124152000] [growingSegmentNum=0] [sealedSegmentNum=1]
# [2024/04/21 22:03:00.123 +02:00] [INFO] [observers/target_observer.go:473] ["observer trigger update current target"] [collectionID=449243396322099465]
# [2024/04/21 22:03:00.124 +02:00] [INFO] [datacoord/services.go:782] ["get recovery info request received"] [traceID=4f166d5aca7f7207532b9258780b2d60] [collectionID=449243396322099465] [partitionIDs="[]"]
# [2024/04/21 22:03:00.124 +02:00] [INFO] [datacoord/handler.go:116] [GetQueryVChanPositions] [collectionID=449243396322099465] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [numOfSegments=1] ["indexed segment"=1]
# [2024/04/21 22:03:00.124 +02:00] [INFO] [datacoord/handler.go:299] ["channel seek position set from channel checkpoint meta"] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [posTs=449243966733287426] [posTime=2024/04/21 22:02:11.496 +02:00]
# [2024/04/21 22:03:00.124 +02:00] [INFO] [datacoord/services.go:797] ["datacoord append channelInfo in GetRecoveryInfo"] [traceID=4f166d5aca7f7207532b9258780b2d60] [collectionID=449243396322099465] [partitionIDs="[]"] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] ["# of unflushed segments"=0] ["# of flushed segments"=1] ["# of dropped segments"=0] ["# of indexed segments"=0]
# [2024/04/21 22:03:01.196 +02:00] [INFO] [runtime/asm_arm64.s:1222] ["expire all shard leader cache"] [database=default] [collections="[arxiv_10000]"]
# [2024/04/21 22:03:07.901 +02:00] [INFO] [gc/gc_tuner.go:90] ["GC Tune done"] ["previous GOGC"=200] ["heapuse "=73] ["total memory"=13580] ["next GC"=77] ["new GOGC"=200] [gc-pause=182.542µs] [gc-pause-end=1713729787901273000]
# [2024/04/21 22:03:10.121 +02:00] [INFO] [datacoord/index_service.go:513] ["receive DescribeIndex request"] [traceID=8eaee368fecc91aaccccd7cc2524cebf] [collectionID=449243396322099465] [indexName=] [timestamp=0]
# [2024/04/21 22:03:10.121 +02:00] [INFO] [datacoord/index_service.go:449] ["completeIndexInfo success"] [collectionID=449243396322099465] [indexID=449243396322099562] [totalRows=12] [indexRows=12] [pendingIndexRows=0] [state=Finished] [failReason=]
# [2024/04/21 22:03:10.121 +02:00] [INFO] [datacoord/index_service.go:560] ["DescribeIndex success"] [traceID=8eaee368fecc91aaccccd7cc2524cebf] [collectionID=449243396322099465] [indexName=]
# [2024/04/21 22:03:10.122 +02:00] [INFO] [querynodev2/services.go:1370] ["sync action"] [traceID=69515dbe9f8485c7a31e0ce90b749f83] [collectionID=449243396322099465] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [currentNodeID=2] [Action=UpdateVersion] [TargetVersion=1713729780123926000]
# [2024/04/21 22:03:10.122 +02:00] [INFO] [delegator/distribution.go:294] ["Update readable segment version"] [oldVersion=1713729770124152000] [newVersion=1713729780123926000] [growingSegmentNum=0] [sealedSegmentNum=1]
# [2024/04/21 22:03:10.122 +02:00] [INFO] [observers/target_observer.go:473] ["observer trigger update current target"] [collectionID=449243396322099465]
# [2024/04/21 22:03:10.122 +02:00] [INFO] [datacoord/services.go:782] ["get recovery info request received"] [traceID=28218a8ef615b0d7be19e0686b51afe8] [collectionID=449243396322099465] [partitionIDs="[]"]
# [2024/04/21 22:03:10.122 +02:00] [INFO] [datacoord/handler.go:116] [GetQueryVChanPositions] [collectionID=449243396322099465] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [numOfSegments=1] ["indexed segment"=1]
# [2024/04/21 22:03:10.122 +02:00] [INFO] [datacoord/handler.go:299] ["channel seek position set from channel checkpoint meta"] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [posTs=449243966733287426] [posTime=2024/04/21 22:02:11.496 +02:00]
# [2024/04/21 22:03:10.122 +02:00] [INFO] [datacoord/services.go:797] ["datacoord append channelInfo in GetRecoveryInfo"] [traceID=28218a8ef615b0d7be19e0686b51afe8] [collectionID=449243396322099465] [partitionIDs="[]"] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] ["# of unflushed segments"=0] ["# of flushed segments"=1] ["# of dropped segments"=0] ["# of indexed segments"=0]
# [2024/04/21 22:03:10.196 +02:00] [INFO] [runtime/asm_arm64.s:1222] ["expire all shard leader cache"] [database=default] [collections="[arxiv_10000]"]
# [2024/04/21 22:03:12.003 +02:00] [INFO] [datacoord/meta.go:1341] ["UpdateChannelCheckpoint done"] [vChannel=by-dev-rootcoord-dml_0_449243396322099465v0] [ts=449243982553415681] [msgID="\ufffd*\ufffd\u0006}\u0008<\u0006"] [time=2024/04/21 22:03:11.845 +02:00]
# [2024/04/21 22:03:20.122 +02:00] [INFO] [datacoord/index_service.go:513] ["receive DescribeIndex request"] [traceID=5aa601769295dd555973afde58a3ec57] [collectionID=449243396322099465] [indexName=] [timestamp=0]
# [2024/04/21 22:03:20.123 +02:00] [INFO] [datacoord/index_service.go:449] ["completeIndexInfo success"] [collectionID=449243396322099465] [indexID=449243396322099562] [totalRows=12] [indexRows=12] [pendingIndexRows=0] [state=Finished] [failReason=]
# [2024/04/21 22:03:20.123 +02:00] [INFO] [datacoord/index_service.go:560] ["DescribeIndex success"] [traceID=5aa601769295dd555973afde58a3ec57] [collectionID=449243396322099465] [indexName=]
# [2024/04/21 22:03:20.123 +02:00] [INFO] [querynodev2/services.go:1370] ["sync action"] [traceID=9e572dc39e605c41a09f7d61db2af9fb] [collectionID=449243396322099465] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [currentNodeID=2] [Action=UpdateVersion] [TargetVersion=1713729790122522000]
# [2024/04/21 22:03:20.123 +02:00] [INFO] [delegator/distribution.go:294] ["Update readable segment version"] [oldVersion=1713729780123926000] [newVersion=1713729790122522000] [growingSegmentNum=0] [sealedSegmentNum=1]
# [2024/04/21 22:03:20.123 +02:00] [INFO] [observers/target_observer.go:473] ["observer trigger update current target"] [collectionID=449243396322099465]
# [2024/04/21 22:03:20.123 +02:00] [INFO] [datacoord/services.go:782] ["get recovery info request received"] [traceID=e3d702cf50e18f1b1f78dd3e9cea03af] [collectionID=449243396322099465] [partitionIDs="[]"]
# [2024/04/21 22:03:20.123 +02:00] [INFO] [datacoord/handler.go:116] [GetQueryVChanPositions] [collectionID=449243396322099465] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [numOfSegments=1] ["indexed segment"=1]
# [2024/04/21 22:03:20.123 +02:00] [INFO] [datacoord/handler.go:299] ["channel seek position set from channel checkpoint meta"] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [posTs=449243982553415681] [posTime=2024/04/21 22:03:11.845 +02:00]
# [2024/04/21 22:03:20.123 +02:00] [INFO] [datacoord/services.go:797] ["datacoord append channelInfo in GetRecoveryInfo"] [traceID=e3d702cf50e18f1b1f78dd3e9cea03af] [collectionID=449243396322099465] [partitionIDs="[]"] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] ["# of unflushed segments"=0] ["# of flushed segments"=1] ["# of dropped segments"=0] ["# of indexed segments"=0]
# [2024/04/21 22:03:22.196 +02:00] [INFO] [runtime/asm_arm64.s:1222] ["expire all shard leader cache"] [database=default] [collections="[arxiv_10000]"]
# [2024/04/21 22:03:23.764 +02:00] [INFO] [gc/gc_tuner.go:90] ["GC Tune done"] ["previous GOGC"=200] ["heapuse "=75] ["total memory"=13537] ["next GC"=82] ["new GOGC"=200] [gc-pause=3.335167ms] [gc-pause-end=1713729803764106000]
# [2024/04/21 22:03:30.122 +02:00] [INFO] [datacoord/index_service.go:513] ["receive DescribeIndex request"] [traceID=f657181af3c0813c8788ed6635ba5161] [collectionID=449243396322099465] [indexName=] [timestamp=0]
# [2024/04/21 22:03:30.122 +02:00] [INFO] [datacoord/index_service.go:449] ["completeIndexInfo success"] [collectionID=449243396322099465] [indexID=449243396322099562] [totalRows=12] [indexRows=12] [pendingIndexRows=0] [state=Finished] [failReason=]
# [2024/04/21 22:03:30.122 +02:00] [INFO] [datacoord/index_service.go:560] ["DescribeIndex success"] [traceID=f657181af3c0813c8788ed6635ba5161] [collectionID=449243396322099465] [indexName=]
# [2024/04/21 22:03:30.123 +02:00] [INFO] [querynodev2/services.go:1370] ["sync action"] [traceID=86380904c148bcdadf1bff8fc5c6dd71] [collectionID=449243396322099465] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [currentNodeID=2] [Action=UpdateVersion] [TargetVersion=1713729800123777000]
# [2024/04/21 22:03:30.123 +02:00] [INFO] [delegator/distribution.go:294] ["Update readable segment version"] [oldVersion=1713729790122522000] [newVersion=1713729800123777000] [growingSegmentNum=0] [sealedSegmentNum=1]
# [2024/04/21 22:03:30.123 +02:00] [INFO] [observers/target_observer.go:473] ["observer trigger update current target"] [collectionID=449243396322099465]
# [2024/04/21 22:03:30.123 +02:00] [INFO] [datacoord/services.go:782] ["get recovery info request received"] [traceID=40e5e9843b740bde7d08817cd57962db] [collectionID=449243396322099465] [partitionIDs="[]"]
# [2024/04/21 22:03:30.123 +02:00] [INFO] [datacoord/handler.go:116] [GetQueryVChanPositions] [collectionID=449243396322099465] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [numOfSegments=1] ["indexed segment"=1]
# [2024/04/21 22:03:30.123 +02:00] [INFO] [datacoord/handler.go:299] ["channel seek position set from channel checkpoint meta"] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] [posTs=449243982553415681] [posTime=2024/04/21 22:03:11.845 +02:00]
# [2024/04/21 22:03:30.123 +02:00] [INFO] [datacoord/services.go:797] ["datacoord append channelInfo in GetRecoveryInfo"] [traceID=40e5e9843b740bde7d08817cd57962db] [collectionID=449243396322099465] [partitionIDs="[]"] [channel=by-dev-rootcoord-dml_0_449243396322099465v0] ["# of unflushed segments"=0] ["# of flushed segments"=1] ["# of dropped segments"=0] ["# of indexed segments"=0]
# [2024/04/21 22:03:31.196 +02:00] [INFO] [runtime/asm_arm64.s:1222] ["expire all shard leader cache"] [database=default] [collections="[arxiv_10000]"]

# %%
# save the df as a csv file
arxiv.to_csv('arxiv100_embedded.csv', index=False)
